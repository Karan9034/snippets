# %%
import pandas as pd

# %%
df = pd.read_csv('stackoverflow_survey_data/survey_results_public.csv')
schema_df = pd.read_csv('stackoverflow_survey_data/survey_results_schema.csv')

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
schema_df
# Out:
#                 Column                                       QuestionText
# 0           Respondent  Randomized respondent ID number (not in order ...
# 1           MainBranch  Which of the following options best describes ...
# 2             Hobbyist                            Do you code as a hobby?
# 3                  Age  What is your age (in years)? If you prefer not...
# 4           Age1stCode  At what age did you write your first line of c...
# ..                 ...                                                ...
# 56  WebframeWorkedWith  Which web frameworks have you done extensive d...
# 57       WelcomeChange  Compared to last year, how welcome do you feel...
# 58         WorkWeekHrs  On average, how many hours per week do you wor...
# 59           YearsCode  Including any education, how many years have y...
# 60        YearsCodePro  NOT including education, how many years have y...
#
# [61 rows x 2 columns]

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
# ...

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3        Yes
# 4        Yes
#         ...
# 64456    Yes
# 64457    Yes
# 64458    Yes
# 64459    Yes
# 64460    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df.loc[:, 'Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3        Yes
# 4        Yes
#         ...
# 64456    Yes
# 64457    Yes
# 64458    Yes
# 64459    Yes
# 64460    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df['Hobbyist'].replace({"Yes": True, "No": False}, inplace=True)

# %%
def func(num):
    if type(num) == str and len(num) == 2:
        return int(num)
    else:
        return 0

# %%
filt = df['Age1stCode'].apply(func) > 18
df = df.loc[filt]

# %%
df
# Out:
#        Respondent                              MainBranch Hobbyist   Age  \
# 1               2          I am a developer by profession    False   NaN
# 8               9          I am a developer by profession    False  30.0
# 11             12          I am a developer by profession    False  49.0
# 24             25          I am a developer by profession    False   NaN
# 27             28  I am a student who is learning to code     True   NaN
# ...           ...                                     ...      ...   ...
# 64443       63077                                     NaN     True   NaN
# 64444       63396                                     NaN     True   NaN
# 64449       63994                                     NaN     True   NaN
# 64451       64104                                     NaN     True   NaN
# 64454       64480                                     NaN     True   NaN
#
#       Age1stCode CompFreq  CompTotal  ConvertedComp         Country  \
# ...

# %%
filt = df['Country'] == 'India'

# %%
df[['WorkWeekHrs', 'Hobbyist', 'ConvertedComp', 'Gender', 'MiscTechDesireNextYear']]
# Out:
#        WorkWeekHrs Hobbyist  ConvertedComp Gender  \
# 1              NaN    False            NaN    NaN
# 8             50.0    False            NaN    Man
# 11            40.0    False        14268.0    Man
# 24            40.0    False            NaN    Man
# 27             NaN     True            NaN    Man
# ...            ...      ...            ...    ...
# 64443          NaN     True            NaN    NaN
# 64444          NaN     True            NaN    NaN
# 64449          NaN     True            NaN    NaN
# 64451          NaN     True            NaN    NaN
# 64454          NaN     True            NaN    NaN
#
#                  MiscTechDesireNextYear
# 1      React Native;TensorFlow;Unity 3D
# 8                                   NaN
# 11                                 .NET
# 24                                  NaN
# 27                                  NaN
# ...                                 ...
# 64443                               NaN
# ...
